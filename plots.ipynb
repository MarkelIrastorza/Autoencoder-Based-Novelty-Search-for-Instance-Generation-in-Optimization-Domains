# %% [markdown]
# EXPERIMENTAL RESULTS

# %%
import numpy as np
import random
import math
from itertools import permutations
import zipfile
import os
import shutil
import glob
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load all types of generated instances

# %%
insert_250_NS_F_IP = np.load('ns1-ip-accelerated/insert_ls_250_gens_NS1_IP.npy')
print('insert_250_NS_F_IP', insert_250_NS_F_IP.shape)

swap_250_NS_F_IP = np.load('ns1-ip-accelerated/swap_ls_250_gens_NS1_IP.npy')
print('swap_250_NS_F_IP', swap_250_NS_F_IP.shape)

two_opt_250_NS_F_IP = np.load('ns1-ip-accelerated/two_opt_ls_250_gens_NS1_IP.npy')
print('two_opt_250_NS_F_IP', two_opt_250_NS_F_IP.shape)

insert_250_NS_AE_IP = np.load('ns2-ip-accelerated/insert_ls_250_gens_NS2_IP.npy')
print('insert_250_NS_AE_IP', insert_250_NS_AE_IP.shape)

swap_250_NS_AE_IP = np.load('ns2-ip-accelerated/swap_ls_250_gens_NS2_IP.npy')
print('swap_250_NS_AE_IP', swap_250_NS_AE_IP.shape)

two_opt_250_NS_AE_IP = np.load('ns2-ip-accelerated/two_opt_ls_250_gens_NS2_IP.npy')
print('two_opt_250_NS_AE_IP', two_opt_250_NS_AE_IP.shape)

insert_1000_NS_F_IP = np.load('ns1-ip-accelerated/insert_ls_1000_gens_NS1_IP.npy')
print('insert_1000_NS_F_IP', insert_1000_NS_F_IP.shape)

swap_1000_NS_F_IP = np.load('ns1-ip-accelerated/swap_ls_1000_gens_NS1_IP.npy')
print('swap_1000_NS_F_IP', swap_1000_NS_F_IP.shape)

two_opt_1000_NS_F_IP = np.load('ns1-ip-accelerated/two_opt_ls_1000_gens_NS1_IP.npy')
print('two_opt_1000_NS_F_IP', two_opt_1000_NS_F_IP.shape)

insert_1000_NS_AE_IP = np.load('ns2-ip-accelerated/insert_ls_1000_gens_NS2_IP.npy')
print('insert_1000_NS_AE_IP', insert_1000_NS_AE_IP.shape)

swap_1000_NS_AE_IP = np.load('ns2-ip-accelerated/swap_ls_1000_gens_NS2_IP.npy')
print('swap_1000_NS_AE_IP', swap_1000_NS_AE_IP.shape)

two_opt_1000_NS_AE_IP = np.load('ns2-ip-accelerated/two_opt_ls_1000_gens_NS2_random.npy')
print('two_opt_1000_NS_AE_IP', two_opt_1000_NS_AE_IP.shape)

insert_250_NS_F_random = np.load('ns1-ip-accelerated/insert_ls_250_gens_NS1_random.npy')
print('insert_250_NS_F_random', insert_250_NS_F_random.shape)

swap_250_NS_F_random = np.load('ns1-ip-accelerated/swap_ls_250_gens_NS1_random.npy')
print('swap_250_NS_F_random', swap_250_NS_F_random.shape)

two_opt_250_NS_F_random = np.load('ns1-ip-accelerated/two_opt_ls_250_gens_NS1_random.npy')
print('two_opt_250_NS_F_random', two_opt_250_NS_F_random.shape)

insert_1000_NS_F_random = np.load('ns1-ip-accelerated/insert_ls_1000_gens_NS1_random.npy')
print('insert_1000_NS_F_random', insert_1000_NS_F_random.shape)

swap_1000_NS_F_random = np.load('ns1-ip-accelerated/swap_ls_1000_gens_NS1_random.npy')
print('swap_1000_NS_F_random', swap_1000_NS_F_random.shape)

two_opt_1000_NS_F_random = np.load('ns1-ip-accelerated/two_opt_ls_1000_gens_NS1_random.npy')
print('two_opt_1000_NS_F_random', two_opt_1000_NS_F_random.shape)

insert_250_NS_AE_random = np.load('ns2-ip-accelerated/insert_ls_250_gens_NS2_random.npy')
print('insert_250_NS_AE_random', insert_250_NS_AE_random.shape)

swap_250_NS_AE_random = np.load('ns2-ip-accelerated/swap_ls_250_gens_NS2_random.npy')
print('swap_250_NS_AE_random', swap_250_NS_AE_random.shape)

two_opt_250_NS_AE_random = np.load('ns2-ip-accelerated/two_opt_ls_250_gens_NS2_random.npy')
print('two_opt_250_NS_AE_random', two_opt_250_NS_AE_random.shape)

insert_1000_NS_AE_random = np.load('ns2-ip-accelerated/insert_ls_1000_gens_NS2_random.npy')
print('insert_1000_NS_AE_random', insert_1000_NS_AE_random.shape)

swap_1000_NS_AE_random = np.load('ns2-ip-accelerated/swap_ls_1000_gens_NS2_random.npy')
print('swap_1000_NS_AE_random', swap_1000_NS_AE_random.shape)

two_opt_1000_NS_AE_random = np.load('ns2-ip-accelerated/two_opt_ls_1000_gens_NS2_random.npy')
print('two_opt_1000_NS_AE_random', two_opt_1000_NS_AE_random.shape)
# Out:
# insert_250_NS_F_IP (1288, 20, 20)
# swap_250_NS_F_IP (1371, 20, 20)
# two_opt_250_NS_F_IP (6, 20, 20)
# insert_250_NS_AE_IP (1711, 20, 20)
# swap_250_NS_AE_IP (470, 20, 20)
# two_opt_250_NS_AE_IP (34, 20, 20)
# insert_1000_NS_F_IP (2069, 20, 20)
# swap_1000_NS_F_IP (3302, 20, 20)
# two_opt_1000_NS_F_IP (75, 20, 20)
# insert_1000_NS_AE_IP (3190, 20, 20)
# swap_1000_NS_AE_IP (1295, 20, 20)
# two_opt_1000_NS_AE_IP (341, 20, 20)
# insert_250_NS_F_random (1885, 20, 20)
# swap_250_NS_F_random (515, 20, 20)
# two_opt_250_NS_F_random (343, 20, 20)
# insert_1000_NS_F_random (3132, 20, 20)
# swap_1000_NS_F_random (1579, 20, 20)
# two_opt_1000_NS_F_random (2282, 20, 20)
# insert_250_NS_AE_random (2382, 20, 20)
# swap_250_NS_AE_random (380, 20, 20)
# two_opt_250_NS_AE_random (135, 20, 20)
# insert_1000_NS_AE_random (4099, 20, 20)
# swap_1000_NS_AE_random (1462, 20, 20)
# two_opt_1000_NS_AE_random (341, 20, 20)

# %% [markdown]
# Set seed for reproducibility

# %%
import torch

def set_global_seed(seed=42):
    random.seed(seed)

    np.random.seed(seed)

    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True)
    
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

set_global_seed(42)

# %% [markdown]
# Define LS algorithms

# %%
set_global_seed(42)

from numba import njit

@njit
def profit_permutation(A, sigma):
    total = 0.0
    N = len(sigma)
    for i in range(N):
        for j in range(i + 1, N):
            total += A[sigma[i], sigma[j]]
    return total
    
def profit(A, algorithm):
    rand_indices = [np.random.randint(0, i+1) for i in range(19, 0, -1)]
    sigma = np.array(algorithm(A, rand_indices))
    idx = sigma.astype(int)

    A_sub = A[np.ix_(idx, idx)]
    total_sum = np.sum(np.triu(A_sub, k=1))
    return total_sum

# %%
from numba import njit

@njit
def two_opt_ls(A, rand_indices):
    N = A.shape[0]
    sigma = np.arange(N)
    for i in range(N-1, 0, -1):
        j = rand_indices[N - 1 - i]
        sigma[i], sigma[j] = sigma[j], sigma[i]

    a = profit_permutation(A, sigma)
    improvement = True

    while improvement:
        improvement = False
        for i in range(N):
            for j in range(i+1, N):
                sigma[i:j+1] = sigma[i:j+1][::-1]
                b = profit_permutation(A, sigma)
                if b > a:
                    a = b
                    improvement = True
                    break
                else:
                    sigma[i:j+1] = sigma[i:j+1][::-1]
            if improvement:
                break

    return sigma

@njit
def swap_ls(A, rand_indices):
    N = A.shape[0]

    sigma = np.arange(N)
    for i in range(N - 1, 0, -1):
        j = rand_indices[N - 1 - i]
        sigma[i], sigma[j] = sigma[j], sigma[i]

    current_profit = profit_permutation(A, sigma)
    improvement = True

    while improvement:
        improvement = False
        for i in range(N):
            for j in range(i + 1, N):
                sigma[i], sigma[j] = sigma[j], sigma[i]
                new_profit = profit_permutation(A, sigma)

                if new_profit > current_profit:
                    current_profit = new_profit
                    improvement = True
                    break
                else:
                    sigma[i], sigma[j] = sigma[j], sigma[i]
            if improvement:
                break

    return sigma

@njit
def insert_ls(A, rand_indices):
    N = A.shape[0]
    sigma = np.arange(N)
    for i in range(N-1, 0, -1):
        j = rand_indices[N - 1 - i]
        sigma[i], sigma[j] = sigma[j], sigma[i]

    a = profit_permutation(A, sigma)
    improvement = True

    while improvement:
        improvement = False
        for i in range(N):
            for j in range(N):
                if i == j:
                    continue
                sigma_copy = sigma.copy()
                temp = sigma_copy[i]
                if i < j:
                    for k in range(i, j):
                        sigma_copy[k] = sigma_copy[k+1]
                else:
                    for k in range(i, j, -1):
                        sigma_copy[k] = sigma_copy[k-1]
                sigma_copy[j] = temp

                b = profit_permutation(A, sigma_copy)
                if b > a:
                    sigma = sigma_copy
                    a = b
                    improvement = True
                    break
            if improvement:
                break

    return sigma

# %% [markdown]
# Load benchmark instances

# %%
set_global_seed(42)

lolib = np.load('benchmark/LOLIB_instances.npy')
print(lolib.shape)
random_instances = np.load('benchmark/random_instances.npy')
print(random_instances.shape)
instances = np.load('benchmark/benchmark_instances.npy')
print(instances.shape)
train_3, test_3 = train_test_split(instances, test_size=0.2, random_state=42)
train = train_3
validation = test_3
test = test_3
training_set, population_set = train_test_split(train,test_size=50 / len(train),random_state=42)

set_global_seed(42)
print(train.shape)
# Out:
# (3188, 20, 20)
# (1500, 20, 20)
# (4688, 20, 20)
# (3750, 20, 20)

# %% [markdown]
# Define and train the autoencoder

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim, hidden_dim=80):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, latent_dim),
            nn.Tanh()
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, input_dim),
            nn.Tanh()
        )

    def forward(self, x):
        z = self.encoder(x)
        out = self.decoder(z)
        return out

def ae_loss(recon_x, x):
    return F.mse_loss(recon_x, x, reduction='mean')

def train_autoencoder(model, data, epochs=50, batch_size=64, lr=1e-3):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        model.train()
        for i in range(0, len(data), batch_size):
            batch = data[i:i+batch_size]
            optimizer.zero_grad()
            recon = model(batch)
            loss = ae_loss(recon, batch)
            loss.backward()
            optimizer.step()

def get_ae_latents(model, data, batch_size=64):
    model.eval()
    latents = []
    with torch.no_grad():
        for i in range(0, len(data), batch_size):
            batch = data[i:i+batch_size]
            z = model.encoder(batch)
            latents.append(z)
    return torch.cat(latents, dim=0)

def train_autoencoder_from_matrices(matrix_data, N, latent_dim=12, hidden_dim=80, epochs=15, batch_size=32, lr=1e-3):
    matrix_array = np.array(matrix_data, dtype=np.float32)

    mask = ~np.eye(N, dtype=bool)
    masked_data = matrix_array[:, mask]

    flat_data = masked_data.reshape(masked_data.shape[0], -1)

    tensor_data = torch.tensor(flat_data, dtype=torch.float32)

    input_dim = tensor_data.shape[1]
    ae_model = Autoencoder(input_dim=input_dim, latent_dim=latent_dim, hidden_dim=hidden_dim)
    train_autoencoder(ae_model, tensor_data, epochs=epochs, batch_size=batch_size, lr=lr)

    latents = get_ae_latents(ae_model, tensor_data, batch_size=batch_size)

    return latents, ae_model

set_global_seed(42)
z, ae_model = train_autoencoder_from_matrices(train, 20)
print(np.max(z.numpy()))
print(np.mean(z.numpy()))
# Out:
# 0.942854
# -0.084914945

# %% [markdown]
# Compute the MSE for the trained autoencoder + for the untrained autoencoder

# %%
import torch
import torch.nn.functional as F

@torch.no_grad()
def dataset_mse_from_matrices(model, matrices, N, batch_size=64):
    arr = np.array(matrices, dtype=np.float32)
    mask = ~np.eye(N, dtype=bool)
    flat = arr[:, mask].reshape(arr.shape[0], -1)
    X = torch.tensor(flat, dtype=torch.float32)

    model.eval()
    se_sum, n_elems = 0.0, 0
    for i in range(0, len(X), batch_size):
        b = X[i:i+batch_size]
        r = model(b)
        se_sum += F.mse_loss(r, b, reduction='sum').item()
        n_elems += b.numel()
    return se_sum / n_elems

val_mse = dataset_mse_from_matrices(ae_model, test_3, N=20)

input_dim = 20*20 - 20
latent_dim = ae_model.encoder[2].out_features
hidden_dim = ae_model.encoder[0].out_features

torch.manual_seed(0)
rand_ae = Autoencoder(input_dim=input_dim, latent_dim=latent_dim, hidden_dim=hidden_dim)

rand_val_mse = dataset_mse_from_matrices(rand_ae, test_3, N=20)
print(f"Trained AE Validation MSE: {val_mse:.8f}")
print(f"Random AE Validation MSE: {rand_val_mse:.8f}")
# Out:
# Trained AE Validation MSE: 0.13711978
# Random AE Validation MSE: 0.62634672

# %% [markdown]
# Define the feature extraction functions for $NS^{F}$ and $NS^{AE}$

# %%
set_global_seed(42)

@njit
def compute_descriptors_NS_F(solution_set):
    pop_size, N, _ = solution_set.shape
    data_matrix = np.zeros((pop_size, 12))

    tril_i = []
    tril_j = []
    for i in range(N):
        for j in range(i):
            tril_i.append(i)
            tril_j.append(j)
    tril_i = np.array(tril_i)
    tril_j = np.array(tril_j)

    for t in range(pop_size):
        A = solution_set[t].copy()

        for i in range(N):
            A[i, i] = 0

        data_matrix[t, 0] = np.mean(A)
        data_matrix[t, 1] = np.var(A)
        data_matrix[t, 2] = np.max(A)
        data_matrix[t, 3] = np.min(A)

        B = np.empty(len(tril_i))
        for idx in range(len(tril_i)):
            i = tril_i[idx]
            j = tril_j[idx]
            B[idx] = (A[i, j] - A[j, i]) / 2

        if B.size > 0:
            data_matrix[t, 4] = np.mean(B)
            data_matrix[t, 5] = np.var(B)
            data_matrix[t, 6] = np.max(B)
            data_matrix[t, 7] = np.min(B)
        else:
            data_matrix[t, 4:8] = 0

        row_col_diff = np.empty(N)
        for i in range(N):
            row_sum = 0.0
            col_sum = 0.0
            for j in range(N):
                row_sum += A[i, j]
                col_sum += A[j, i]
            row_col_diff[i] = (row_sum - col_sum) / (2 * N)

        data_matrix[t, 8] = np.mean(row_col_diff)
        data_matrix[t, 9] = np.var(row_col_diff)
        data_matrix[t,10] = np.max(row_col_diff)
        data_matrix[t,11] = np.min(row_col_diff)

    return data_matrix

# %%
set_global_seed(42)

def compute_descriptors_NS_AE(solution_set):

    N = solution_set.shape[1]
    mask = ~np.eye(N, dtype=bool)
    masked_data = solution_set[:,mask]
    flat = masked_data.reshape(masked_data.shape[0], -1)
    tens = torch.tensor(np.array(flat), dtype=torch.float32)
    ae_model.eval()
    with torch.no_grad():
        data_matrix = ae_model.encoder(tens).cpu().numpy().astype(np.float32)
    return data_matrix

# %% [markdown]
# Functions used to define and use the feature-based and autoencoder-based PCA spaces

# %%
set_global_seed(42)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

def fit_pca_reference(*data_matrices, padding=0.2, flip_x=True):
    matrix = np.vstack(data_matrices).reshape(-1, data_matrices[0].shape[1])
    scaler = StandardScaler()
    matrix_std = scaler.fit_transform(matrix)

    pca = PCA(n_components=2, svd_solver='full', random_state=42)
    reduced_data = pca.fit_transform(matrix_std)

    signs = np.sign(pca.components_.sum(axis=1))
    signs[signs == 0] = 1

    if flip_x:
        signs[0] *= -1

    pca.components_ *= signs[:, None]
    reduced_data *= signs

    x_min, x_max = reduced_data[:, 0].min(), reduced_data[:, 0].max()
    y_min, y_max = reduced_data[:, 1].min(), reduced_data[:, 1].max()

    x_range = x_max - x_min
    y_range = y_max - y_min

    x_min -= x_range * padding/4
    x_max += x_range * padding/4
    y_min -= y_range * padding
    y_max += y_range * padding

    axis_limits = (x_min, x_max, y_min, y_max)

    return scaler, pca, axis_limits


def plot_with_fitted_pca(name, *data_matrices, scaler, pca, axis_limits=None, labels=None, title="PCA Projection"):
    sizes = [len(dm) for dm in data_matrices]
    cumulative_sizes = np.cumsum([0] + sizes)

    matrix = np.vstack(data_matrices).reshape(len(np.vstack(data_matrices)), -1)
    matrix_std = scaler.transform(matrix)
    reduced_data = pca.transform(matrix_std)

    plt.figure(figsize=(8, 5))
    default_colors = ['#1f77b4', '#ff7f0e', '#d62728', '#2ca02c', '#9467bd', '#8c564b']
    default_markers = ['o', '*', 's', 'P', '^', 'x']

    for i in range(len(data_matrices)):
        group = reduced_data[cumulative_sizes[i]:cumulative_sizes[i+1], :]
        label = labels[i] if labels and i < len(labels) else f"Grupo {i+1}"
        color = default_colors[i % len(default_colors)]
        marker = default_markers[i % len(default_markers)]
        plt.scatter(group[:, 0], group[:, 1], s=0.8, marker=marker, label=label, color=color)

    if axis_limits:
        x_min, x_max, y_min, y_max = axis_limits
        plt.xlim(x_min, x_max)
        plt.ylim(y_min, y_max)


    plt.title(title, fontsize=14)
    plt.legend(loc='best', frameon=True)
    plt.grid(False)
    plt.tight_layout()
    plt.show()

    # plt.savefig(f"{name}.png", dpi=1000, bbox_inches='tight')
    # plt.close()

# %% [markdown]
# Fix both spaces

# %%
set_global_seed(42)

scaler, pca, axis_limits = fit_pca_reference(compute_descriptors_NS_AE(training_set))

scaler_2, pca_2, axis_limits_2 = fit_pca_reference(compute_descriptors_NS_F(training_set), padding=0.2, flip_x=False)

# %% [markdown]
# Random instances for reference

# %%
import numpy as np

def generate_beta_instances(num_instances=500, shape=(20, 20)):
    instances = np.random.beta(2, 5, size=(num_instances, *shape))
    instances = instances * 2 - 1
    return instances


def generate_uniform_instances(num_instances=500, shape=(20, 20)):
    instances = np.random.uniform(-1, 1, size=(num_instances, *shape))
    return instances


def generate_normal_instances(num_instances=500, shape=(20, 20), sigma=0.3):
    instances = np.random.normal(0, sigma, size=(num_instances, *shape))
    instances = np.clip(instances, -1, 1)
    return instances

beta_data = generate_beta_instances()
uniform_data = generate_uniform_instances()
normal_data = generate_normal_instances()

print(beta_data.shape)
print(uniform_data.shape)
print(normal_data.shape)
# Out:
# (500, 20, 20)
# (500, 20, 20)
# (500, 20, 20)

# %% [markdown]
# Plots $NS^{F}$ vs $NS^{AE}$

# %%
set_global_seed(42)

plot_with_fitted_pca("lolib", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(lolib), scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Random", "LOLIB"], title="Autoencoder-based descriptors base PCA")

plot_with_fitted_pca("lolib_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(lolib), scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Random", "LOLIB"], title="Feature-based descriptors base PCA")

plot_with_fitted_pca("Benchmark instances NS_AE", compute_descriptors_NS_AE(lolib), compute_descriptors_NS_AE(beta_data),compute_descriptors_NS_AE(uniform_data),compute_descriptors_NS_AE(normal_data),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["LOLIB", "Beta", "Uniform", "Normal"], title=r"Benchmark instances in the autoencoder-based PCA space")

plot_with_fitted_pca("Benchmark instances NS_F", compute_descriptors_NS_F(lolib), compute_descriptors_NS_F(beta_data),compute_descriptors_NS_F(uniform_data),compute_descriptors_NS_F(normal_data),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["LOLIB", "Beta", "Uniform", "Normal"], title=r"Benchmark instances in the feature-based PCA space")

plot_with_fitted_pca("250_IP_NS_F_in_NS_AE", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(insert_250_NS_F_IP),compute_descriptors_NS_AE(swap_250_NS_F_IP),compute_descriptors_NS_AE(two_opt_250_NS_F_IP),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"250 generations of $NS^{F}$ in the autoencoder-based PCA space")

plot_with_fitted_pca("1000_IP_NS_F_in_NS_AE", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(insert_1000_NS_F_IP),compute_descriptors_NS_AE(swap_1000_NS_F_IP),compute_descriptors_NS_AE(two_opt_1000_NS_F_IP),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"1000 generations of $NS^{F}$ in the autoencoder-based PCA space")

plot_with_fitted_pca("250_IP_NS_AE_in_NS_AE", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(insert_250_NS_AE_IP),compute_descriptors_NS_AE(swap_250_NS_AE_IP),compute_descriptors_NS_AE(two_opt_250_NS_AE_IP),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"250 generations of $NS^{AE}$ in the autoencoder-based PCA space")

plot_with_fitted_pca("1000_IP_NS_AE_in_NS_AE", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(insert_1000_NS_AE_IP),compute_descriptors_NS_AE(swap_1000_NS_AE_IP),compute_descriptors_NS_AE(two_opt_1000_NS_AE_IP),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"1000 generations of $NS^{AE}$ in the autoencoder-based PCA space")

# %%
set_global_seed(42)

plot_with_fitted_pca("250_IP_NS_F_in_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(insert_250_NS_F_IP),compute_descriptors_NS_F(swap_250_NS_F_IP),compute_descriptors_NS_F(two_opt_250_NS_F_IP),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Benchamrk", "Insert", "Swap", "2-opt"], title=r"250 generations of $NS^{F}$ in the feature-based PCA space")

plot_with_fitted_pca("1000_IP_NS_F_in_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(insert_1000_NS_F_IP),compute_descriptors_NS_F(swap_1000_NS_F_IP),compute_descriptors_NS_F(two_opt_1000_NS_F_IP),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"1000 generations of $NS^{F}$ in the feature-based PCA space")

plot_with_fitted_pca("250_IP_NS_AE_in_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(insert_250_NS_AE_IP),compute_descriptors_NS_F(swap_250_NS_AE_IP),compute_descriptors_NS_F(two_opt_250_NS_AE_IP),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"250 generations of $NS^{AE}$ in the feature-based PCA space")

plot_with_fitted_pca("1000_IP_NS_AE_in_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(insert_1000_NS_AE_IP),compute_descriptors_NS_F(swap_1000_NS_AE_IP),compute_descriptors_NS_F(two_opt_1000_NS_AE_IP),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"1000 generations of $NS^{AE}$ in the feature-based PCA space")

# %%
set_global_seed(42)

plot_with_fitted_pca("250_random_NS_AE_in_NS_AE", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(insert_250_NS_AE_random),compute_descriptors_NS_AE(swap_250_NS_AE_random),compute_descriptors_NS_AE(two_opt_250_NS_AE_random),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"random 250 generations of $NS^{AE}$ in the autoencoder-based PCA space")

plot_with_fitted_pca("1000_random_NS_AE_in_NS_AE", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(insert_1000_NS_AE_random),compute_descriptors_NS_AE(swap_1000_NS_AE_random),compute_descriptors_NS_AE(two_opt_1000_NS_AE_random),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"random 1000 generations of $NS^{AE}$ in the autoencoder-based PCA space")

plot_with_fitted_pca("250_random_NS_AE_in_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(insert_250_NS_AE_random),compute_descriptors_NS_F(swap_250_NS_AE_random),compute_descriptors_NS_F(two_opt_250_NS_AE_random),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"random 250 generations of $NS^{AE}$ in the feature-based PCA space")

plot_with_fitted_pca("1000_random_NS_AE_in_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(insert_1000_NS_AE_random),compute_descriptors_NS_F(swap_1000_NS_AE_random),compute_descriptors_NS_F(two_opt_1000_NS_AE_random),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"random 1000 generations of $NS^{AE}$ in the feature-based PCA space")

plot_with_fitted_pca("250_random_NS_F_in_NS_AE", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(insert_250_NS_F_random),compute_descriptors_NS_AE(swap_250_NS_F_random),compute_descriptors_NS_AE(two_opt_250_NS_F_random),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"random 250 generations of $NS^{F}$ in the autoencoder-based PCA space")

plot_with_fitted_pca("1000_random_NS_F_in_NS_AE", compute_descriptors_NS_AE(training_set), compute_descriptors_NS_AE(insert_1000_NS_F_random),compute_descriptors_NS_AE(swap_1000_NS_F_random),compute_descriptors_NS_AE(two_opt_1000_NS_F_random),
                     scaler=scaler, pca=pca, axis_limits=axis_limits, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"random 1000 generations of $NS^{F}$ in the autoencoder-based PCA space")

plot_with_fitted_pca("250_random_NS_F_in_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(insert_250_NS_F_random),compute_descriptors_NS_F(swap_250_NS_F_random),compute_descriptors_NS_F(two_opt_250_NS_F_random),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"random 250 generations of $NS^{F}$ in the feature-based PCA space")

plot_with_fitted_pca("1000_random_NS_F_in_NS_F", compute_descriptors_NS_F(training_set), compute_descriptors_NS_F(insert_1000_NS_F_random),compute_descriptors_NS_F(swap_1000_NS_F_random),compute_descriptors_NS_F(two_opt_1000_NS_F_random),
                     scaler=scaler_2, pca=pca_2, axis_limits=axis_limits_2, labels=["Benchmark", "Insert", "Swap", "2-opt"], title=r"random 1000 generations of $NS^{F}$ in the feature-based PCA space")

# %% [markdown]
# Load data for different $\phi$

# %%
descriptor_dict = {}

methods = ['insert', 'swap', 'two_opt']
suffixes = ['0', '0_1', '0_25', '0_4', '0_55', '0_7', '1']

for method in methods:
    for suffix in suffixes:
        key = f'{method}_ls_1000_gens_NS2_{suffix}'
        filename = f'changin-phi/{key}.npy'
        try:
            perturbed_data = np.load(filename, allow_pickle=True)
            
            descriptors = compute_descriptors_NS_AE(perturbed_data)
            
            descriptor_dict[key] = descriptors
            print(f"{key}: {descriptors.shape}")
        except Exception as e:
            print(f"Error in {key}: {e}")


operator_groups = {
    'insert': [k for k in descriptor_dict if k.startswith('insert')],
    'swap': [k for k in descriptor_dict if k.startswith('swap')],
    'two_opt': [k for k in descriptor_dict if k.startswith('two_opt')],
}

descriptor_dict_2 = {}

for method in methods:
    for suffix in suffixes:
        key = f'{method}_ls_1000_gens_NS2_{suffix}'
        filename = f'changin-phi/{key}.npy'
        try:
            perturbed_data = np.load(filename, allow_pickle=True)
            
            descriptors = compute_descriptors_NS_F(perturbed_data)
            
            descriptor_dict_2[key] = descriptors
            print(f"{key}: {descriptors.shape}")
        except Exception as e:
            print(f"Error in {key}: {e}")


operator_groups_2 = {
    'insert': [k for k in descriptor_dict_2 if k.startswith('insert')],
    'swap': [k for k in descriptor_dict_2 if k.startswith('swap')],
    'two_opt': [k for k in descriptor_dict_2 if k.startswith('two_opt')],
}
# Out:
# Error in insert_ls_1000_gens_NS2_0: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS2_0.npy'
# Error in insert_ls_1000_gens_NS2_0_1: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS2_0_1.npy'
# Error in insert_ls_1000_gens_NS2_0_25: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS2_0_25.npy'
# Error in insert_ls_1000_gens_NS2_0_4: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS2_0_4.npy'
# Error in insert_ls_1000_gens_NS2_0_55: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS2_0_55.npy'
# Error in insert_ls_1000_gens_NS2_0_7: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS2_0_7.npy'
# Error in insert_ls_1000_gens_NS2_1: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS2_1.npy'
# Error in swap_ls_1000_gens_NS2_0: [Errno 2] No such file or directory: 'changin-phi/swap_ls_1000_gens_NS2_0.npy'
# ...

# %%
import matplotlib.pyplot as plt

xs = [0, 0.1, 0.25, 0.4, 0.55, 0.7, 0.85, 1.0]

insert = {
    0.0: 12813,
    0.1: 13788,
    0.25: 11849,
    0.4: 9175,
    0.55: 8696,
    0.7: 5185,
    0.85: 3190,
    1.0: 1364,
}

swap = {
    0.0: 34,
    0.1: 64,
    0.25: 192,
    0.4: 730,
    0.55: 1217,
    0.7: 2881,
    0.85: 1295,
    1.0: 302,
}

two_opt = {
    0.0: 1,
    0.1: 1,
    0.25: 4,
    0.4: 218,
    0.55: 493,
    0.7: 414,
    0.85: 341,
    1.0: 263,
}

y_insert = [insert.get(x, np.nan) for x in xs]
y_swap   = [swap.get(x, np.nan) for x in xs]
y_two    = [two_opt.get(x, np.nan) for x in xs]

y_total = list(np.nansum([y_insert, y_swap, y_two], axis=0))

plt.figure(figsize=(10, 6))

plt.plot(xs, y_insert, marker='o', label='Insert')
plt.plot(xs, y_swap, marker='o', label='Swap')
plt.plot(xs, y_two, marker='o', label='2-Opt')
plt.plot(xs, y_total, marker='o', linewidth=2, label='Total')

plt.xticks(xs, [str(x) for x in xs])
plt.xlabel(r'$\phi$')
plt.ylabel('# Instances')
plt.title('Comparison of the amount of instances generated for each LS algorithm')
plt.grid(True, linestyle='--', alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()
# plt.savefig("Instances generated different phi", dpi=1000, bbox_inches='tight')
# plt.close()

# %%
descriptor_dict_3 = {}

methods = ['insert', 'swap', 'two_opt']
suffixes = ['0', '0_1', '0_25', '0_4', '0_55', '0_7', '1']

for method in methods:
    for suffix in suffixes:
        key = f'{method}_ls_1000_gens_NS1_{suffix}'
        filename = f'changin-phi/{key}.npy'
        try:
            perturbed_data = np.load(filename, allow_pickle=True)
            
            descriptors = compute_descriptors_NS_AE(perturbed_data)
            
            descriptor_dict_3[key] = descriptors
            print(f"{key}: {descriptors.shape}")
        except Exception as e:
            print(f"Error in {key}: {e}")


operator_groups_3 = {
    'insert': [k for k in descriptor_dict_3 if k.startswith('insert')],
    'swap': [k for k in descriptor_dict_3 if k.startswith('swap')],
    'two_opt': [k for k in descriptor_dict_3 if k.startswith('two_opt')],
}

descriptor_dict_4 = {}

for method in methods:
    for suffix in suffixes:
        key = f'{method}_ls_1000_gens_NS1_{suffix}'
        filename = f'changin-phi/{key}.npy'
        try:
            perturbed_data = np.load(filename, allow_pickle=True)
            
            descriptors = compute_descriptors_NS_F(perturbed_data)
            
            descriptor_dict_4[key] = descriptors
            print(f"{key}: {descriptors.shape}")
        except Exception as e:
            print(f"Error in {key}: {e}")


operator_groups_4 = {
    'insert': [k for k in descriptor_dict_4 if k.startswith('insert')],
    'swap': [k for k in descriptor_dict_4 if k.startswith('swap')],
    'two_opt': [k for k in descriptor_dict_4 if k.startswith('two_opt')],
}
# Out:
# Error in insert_ls_1000_gens_NS1_0: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS1_0.npy'
# Error in insert_ls_1000_gens_NS1_0_1: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS1_0_1.npy'
# Error in insert_ls_1000_gens_NS1_0_25: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS1_0_25.npy'
# Error in insert_ls_1000_gens_NS1_0_4: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS1_0_4.npy'
# Error in insert_ls_1000_gens_NS1_0_55: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS1_0_55.npy'
# Error in insert_ls_1000_gens_NS1_0_7: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS1_0_7.npy'
# Error in insert_ls_1000_gens_NS1_1: [Errno 2] No such file or directory: 'changin-phi/insert_ls_1000_gens_NS1_1.npy'
# Error in swap_ls_1000_gens_NS1_0: [Errno 2] No such file or directory: 'changin-phi/swap_ls_1000_gens_NS1_0.npy'
# ...

# %% [markdown]
# Plots for different $\phi$ values

# %%
def group_by_operator(descriptor_dict, keys):
    return np.concatenate([descriptor_dict[k] for k in keys if k in descriptor_dict])

original_data = compute_descriptors_NS_AE(training_set)

for i in range(7):
    suffix = ['0', '0_1', '0_25', '0_4', '0_55', '0_7', '1'][i]
    number = ['0', '0.1', '0.25', '0.4', '0.55', '0.7', '1'][i]
    plot_with_fitted_pca(suffix,
        original_data,
        *[
            group_by_operator(descriptor_dict, [f'{method}_ls_1000_gens_NS2_{suffix}'])
            for method in operator_groups.keys()
        ],
        scaler=scaler,
        pca=pca,
        axis_limits=axis_limits,
        labels=['Benchmark','Insert','Swap','2-Opt'],
        title=f"Generated instances for $\phi$={number}"
    )

def group_by_operator(descriptor_dict, keys):
    return np.concatenate([descriptor_dict[k] for k in keys if k in descriptor_dict])

original_data = compute_descriptors_NS_AE(training_set)

insert_all  = group_by_operator(descriptor_dict, operator_groups['insert'])
swap_all    = group_by_operator(descriptor_dict, operator_groups['swap'])
twoopt_all  = group_by_operator(descriptor_dict, operator_groups['two_opt'])

plot_with_fitted_pca(
    "all_phi",
    original_data,
    insert_all,
    swap_all,
    twoopt_all,
    scaler=scaler,
    pca=pca,
    axis_limits=axis_limits,
    labels=['Benchmark', 'Insert', 'Swap', '2-Opt'],
    title=r"Generated instances for all $\phi$"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 11
#       7     suffix = ['0', '0_1', '0_25', '0_4', '0_55', '0_7', '1'][i]
#       8     number = ['0', '0.1', '0.25', '0.4', '0.55', '0.7', '1'][i]
#       9     plot_with_fitted_pca(suffix,
#      10         original_data,
# ---> 11         *[
#      12             group_by_operator(descriptor_dict, [f'{method}_ls_1000_gens_NS2_{suffix}'])
#      13             for method in operator_groups.keys()
#      14         ],
#      15         scaler=scaler,
#      16         pca=pca,
#      17         axis_limits=axis_limits,
#      18         labels=['Benchmark','Insert','Swap','2-Opt'],
#      19         title=f"Generated instances for $\phi$={number}"
#      20     )
#      22 def group_by_operator(descriptor_dict, keys):
# ...

# %% [markdown]
# Define U metric

# %%
from scipy.spatial.distance import jensenshannon
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

set_global_seed(42)

def compute_U_metric(descriptors, scaler, pca, grid_size=66, xlim=None, ylim=None):
    descriptors_scaled = scaler.transform(descriptors)
    delta = pca.transform(descriptors_scaled)

    if xlim is None or ylim is None:
        raise ValueError("xlim and ylim must be provided to ensure consistent PCA area.")

    xmin, xmax = xlim
    ymin, ymax = ylim

    delta_norm = np.empty_like(delta)
    delta_norm[:, 0] = (delta[:, 0] - xmin) / (xmax - xmin + 1e-10)
    delta_norm[:, 1] = (delta[:, 1] - ymin) / (ymax - ymin + 1e-10)

    delta_norm = np.clip(delta_norm, 0, 1)

    grid_counts = np.zeros((grid_size, grid_size))
    for x, y in delta_norm:
        i = min(int(x * grid_size), grid_size - 1)
        j = min(int(y * grid_size), grid_size - 1)
        grid_counts[i, j] += 1

    P_delta = grid_counts.flatten() / np.sum(grid_counts)

    UD = np.ones_like(P_delta) / len(P_delta)

    jsd = jensenshannon(P_delta, UD, base=2)**2
    U_score = 1.0 - jsd

    return U_score

# %% [markdown]
# Compute U metric $NS^{F}$ vs $NS^{AE}$

# %%
set_global_seed(42)

xlim = axis_limits[0:2]
ylim = axis_limits[2:4]
xlim_2 = axis_limits_2[0:2]
ylim_2 = axis_limits_2[2:4]


descriptors = compute_descriptors_NS_F(np.concatenate((insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP)))
U = compute_U_metric(descriptors, scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2)
print("U metric 1000 IP NS_F in NS_F:", U)


descriptors = compute_descriptors_NS_AE(np.concatenate((insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP)))
U = compute_U_metric(descriptors, scaler, pca, xlim=xlim, ylim=ylim)
print("U metric 1000 IP NS_F in NS_AE:", U)


descriptors = compute_descriptors_NS_F(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP)))
U = compute_U_metric(descriptors, scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2)
print("U metric 1000 IP NS_AE in NS_F:", U)


descriptors = compute_descriptors_NS_AE(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP)))
U = compute_U_metric(descriptors, scaler, pca, xlim=xlim, ylim=ylim)
print("U metric 1000 IP NS_AE in NS_AE:", U)

descriptors = compute_descriptors_NS_F(np.concatenate((training_set, insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP)))
U = compute_U_metric(descriptors, scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2)
print("U metric 1000 IP NS_F in NS_F:", U)

descriptors = compute_descriptors_NS_AE(np.concatenate((training_set, insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP)))
U = compute_U_metric(descriptors, scaler, pca, xlim=xlim, ylim=ylim)
print("U metric 1000 IP NS_F in NS_AE:", U)

descriptors = compute_descriptors_NS_F(np.concatenate((training_set, insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP)))
U = compute_U_metric(descriptors, scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2)
print("U metric 1000 IP NS_AE in NS_F:", U)

descriptors = compute_descriptors_NS_AE(np.concatenate((training_set, insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP)))
U = compute_U_metric(descriptors, scaler, pca, xlim=xlim, ylim=ylim)
print("U metric 1000 IP NS_AE in NS_AE:", U)
# Out:
# U metric 1000 IP NS_F in NS_F: 0.17925896384157736
# U metric 1000 IP NS_F in NS_AE: 0.19220434885022297
# U metric 1000 IP NS_AE in NS_F: 0.15015973533271143
# U metric 1000 IP NS_AE in NS_AE: 0.2701320342024194
# U metric 1000 IP NS_F in NS_F: 0.26295642901213867
# U metric 1000 IP NS_F in NS_AE: 0.28633612740994874
# U metric 1000 IP NS_AE in NS_F: 0.2574348643540908
# U metric 1000 IP NS_AE in NS_AE: 0.3265143411600697

# %%
set_global_seed(42)

xlim = axis_limits[0:2]
ylim = axis_limits[2:4]
xlim_2 = axis_limits_2[0:2]
ylim_2 = axis_limits_2[2:4]

descriptors = compute_descriptors_NS_F(training_set)
U = compute_U_metric(descriptors, scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2)
print("U metric training_set in NS_F:", U)

descriptors = compute_descriptors_NS_AE(training_set)
U = compute_U_metric(descriptors, scaler, pca, xlim=xlim, ylim=ylim)
print("U metric training_set in NS_AE:", U)

descriptors = compute_descriptors_NS_F(np.concatenate((training_set, insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP)))
U = compute_U_metric(descriptors, scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2) - compute_U_metric(compute_descriptors_NS_F(training_set), scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2)
print("U metric difference 1000 IP NS_F in NS_F:", U)

descriptors = compute_descriptors_NS_AE(np.concatenate((training_set, insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP)))
U = compute_U_metric(descriptors, scaler, pca, xlim=xlim, ylim=ylim) - compute_U_metric(compute_descriptors_NS_AE(training_set), scaler, pca, xlim=xlim, ylim=ylim)
print("U metric difference 1000 IP NS_F in NS_AE:", U)

descriptors = compute_descriptors_NS_F(np.concatenate((training_set, insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP)))
U = compute_U_metric(descriptors, scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2) - compute_U_metric(compute_descriptors_NS_F(training_set), scaler_2, pca_2, xlim=xlim_2, ylim=ylim_2)
print("U metric difference 1000 IP NS_AE in NS_F:", U)
descriptors = compute_descriptors_NS_AE(np.concatenate((training_set, insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP)))
U = compute_U_metric(descriptors, scaler, pca, xlim=xlim, ylim=ylim) - compute_U_metric(compute_descriptors_NS_AE(training_set), scaler, pca, xlim=xlim, ylim=ylim)
print("U metric difference 1000 IP NS_AE in NS_AE:", U)
# Out:
# U metric training_set in NS_F: 0.2231897660771337
# U metric training_set in NS_AE: 0.26371077315170444
# U metric difference 1000 IP NS_F in NS_F: 0.03976666293500497
# U metric difference 1000 IP NS_F in NS_AE: 0.0226253542582443
# U metric difference 1000 IP NS_AE in NS_F: 0.0342450982769571
# U metric difference 1000 IP NS_AE in NS_AE: 0.06280356800836528

# %% [markdown]
# U metric for different $\phi$ values

# %%
import pandas as pd
import matplotlib.pyplot as plt

methods   = ['insert', 'swap', 'two_opt']
suffixes  = ['0', '0_1', '0_25', '0_4', '0_55', '0_7', '0_85', '1']
phi_value = {'0': 0.0, '0_1': 0.1, '0_25': 0.25, '0_4': 0.4, '0_55': 0.55, '0_7': 0.7, '0_85': 0.85, '1': 1.0}

def load_instances(method: str, suffix: str):
    if suffix == '0_85':
        var_name = f"{method}_ls_1000_gens_NS2_IP"
        if var_name in globals():
            return globals()[var_name]
        path = f"changin-phi/{var_name}.npy"
        try:
            return np.load(path, allow_pickle=True)
        except Exception as e:
            raise FileNotFoundError(f"{var_name} not found in {path}. Info: {e}")
    else:
        key  = f"{method}_ls_1000_gens_NS2_{suffix}"
        path = f"changin-phi/{key}.npy"
        try:
            return np.load(path, allow_pickle=True)
        except Exception as e:
            raise FileNotFoundError(f"Can't load {path}. Info: {e}")

def compute_U_by_phi_with_train() -> dict:
    U_by_phi = {}
    for s in suffixes:
        arrays = [load_instances(m, s) for m in methods]
        arrays.append(training_set)
        instances_phi = np.concatenate(arrays, axis=0)

        desc_phi = compute_descriptors_NS_AE(instances_phi)
        U_phi = compute_U_metric(desc_phi, scaler, pca, xlim=xlim, ylim=ylim)
        U_by_phi[s] = float(U_phi)

    return U_by_phi

U_with = compute_U_by_phi_with_train()

df_U = pd.DataFrame({
    "phi_suffix": suffixes,
    "phi": [phi_value[s] for s in suffixes],
    "U_with_benchmark": [U_with[s] for s in suffixes],
}).sort_values("phi").reset_index(drop=True)

print(df_U)

plt.figure(figsize=(9,5))

line_main, = plt.plot(
    df_U["phi"], df_U["U_with_benchmark"],
    marker='o',
    label='Generated + Benchmark instances'
)

plt.plot(
    [0, 1], [0.2637, 0.2637],
    color='red',
    linestyle=line_main.get_linestyle(),
    linewidth=line_main.get_linewidth(),
    label='Benchmark instances'
)

plt.plot(
    df_U["phi"], [0.2637] * len(df_U),
    linestyle='None',
    marker=line_main.get_marker(),
    markersize=line_main.get_markersize(),
    markerfacecolor='red',
    markeredgecolor='red',
    label='_nolegend_'
)

plt.xticks(df_U["phi"], [str(v) for v in df_U["phi"]])
plt.xlabel(r"$\phi$")
plt.ylabel(r"$U(\varphi)$")
plt.title(r"U metric with benchmark instances for different $\phi$")
plt.grid(True, linestyle='--', alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()
# plt.savefig("U_metric_with_training.png", dpi=1000, bbox_inches='tight') 
# plt.close()
# Out:
#   phi_suffix   phi  U_with_benchmark
# 0          0  0.00          0.308780
# 1        0_1  0.10          0.316804
# 2       0_25  0.25          0.332317
# 3        0_4  0.40          0.343129
# 4       0_55  0.55          0.345655
# 5        0_7  0.70          0.323280
# 6       0_85  0.85          0.330591
# 7          1  1.00          0.314359

# %%
all_generated_desc = np.concatenate(list(descriptor_dict.values()), axis=0)

original_desc = compute_descriptors_NS_AE(training_set)

all_desc = np.concatenate([all_generated_desc, original_desc], axis=0)

U_all = compute_U_metric(all_desc, scaler, pca, xlim=xlim, ylim=ylim)

print(f"U (all φ + training) = {U_all:.6f}")
# Out:
# U (all φ + training) = 0.349189

# %% [markdown]
# Define profit differences

# %%
set_global_seed(42)

def run_algorithm(A, algo):
    return profit(A, algo)

def compare_algorithms(population, repetitions=3):
    ALGORITHMS = {
        'insert': insert_ls,
        'swap': swap_ls,
        'two_opt': two_opt_ls
    }

    algos = list(ALGORITHMS.keys())
    num_instances = population.shape[0]

    profits = {algo: np.zeros(num_instances) for algo in algos}

    for i in range(num_instances):
        A = population[i]
        for algo in algos:
            total_profit = 0.0
            for _ in range(repetitions):
                total_profit += run_algorithm(A, ALGORITHMS[algo])
            profits[algo][i] = total_profit / repetitions

    diff_insert_swap = profits['insert'] - profits['swap']
    diff_swap_insert = profits['swap'] - profits['insert']
    
    diff_insert_two_opt = profits['insert'] - profits['two_opt']
    diff_two_opt_insert = profits['two_opt'] - profits['insert']
    
    diff_swap_two_opt = profits['swap'] - profits['two_opt']
    diff_two_opt_swap = profits['two_opt'] - profits['swap']

    return {
        'insert - swap': diff_insert_swap,
        'swap - insert': diff_swap_insert,
        'insert - two_opt': diff_insert_two_opt,
        'two_opt - insert': diff_two_opt_insert,
        'swap - two_opt': diff_swap_two_opt,
        'two_opt - swap': diff_two_opt_swap,
        'raw': profits
    }

# %% [markdown]
# Compute profit differences

# %%
set_global_seed(42)

results = compare_algorithms(training_set)

# %% [markdown]
# Boxplot of the profit differences

# %%
import matplotlib.pyplot as plt

set_global_seed(42)

print("Mean insert - swap:", np.mean(results['insert - swap']))
print("Mean insert - two_opt:", np.mean(results['insert - two_opt']))
print("Mean swap - two_opt:", np.mean(results['swap - two_opt']))

plt.boxplot([
    results['insert - swap'],
    results['insert - two_opt'],
    results['swap - two_opt']
], labels=['insert - swap', 'insert - 2-opt', 'swap - 2-opt'])

plt.title("Profit difference between algorithms")
plt.ylabel("Profit difference")
plt.grid(True)
plt.show()
# plt.savefig("Boxplot algorithm difference", dpi=1000, bbox_inches='tight')
# plt.close()
# Out:
# Mean insert - swap: 2.116043502120511
# Mean insert - two_opt: 4.371422126727088
# Mean swap - two_opt: 2.255378624606577

# %% [markdown]
# Define heatmap plot

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np

set_global_seed(42)

def plot_pca_profit_difference(title_for_save, data_matrix, profit_diff, scaler, pca,
                               title='Profit Difference',
                               cmap='coolwarm',
                               axis_limits=None,
                               color_range=None):
    n_instances = data_matrix.shape[0]

    if len(data_matrix.shape) == 3:
        data_matrix = data_matrix.reshape(n_instances, -1)

    X_scaled = scaler.transform(data_matrix)
    X_pca = pca.transform(X_scaled)

    vmin, vmax = color_range if color_range else (profit_diff.min(), profit_diff.max())

    plt.figure(figsize=(8, 5))
    scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1],
                          c=profit_diff,
                          cmap=cmap,
                          vmin=vmin,
                          vmax=vmax,
                          s=10,
                          edgecolor='k',
                          linewidth=0.2)

    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.title(title)

    cbar = plt.colorbar(scatter)
    cbar.set_label('Profit difference')

    if axis_limits is not None:
        x_min, x_max, y_min, y_max = axis_limits
        plt.xlim(x_min, x_max)
        plt.ylim(y_min, y_max)

    plt.grid(True)
    plt.tight_layout()
    plt.show()
    # plt.savefig(title_for_save, dpi=1000, bbox_inches='tight')
    # plt.close()

# %% [markdown]
# Define the color range

# %%
set_global_seed(42)

descriptors = compute_descriptors_NS_AE(training_set)

print(min(results['two_opt - swap']))
color_range = (-25, 25)
# Out:
# -13.825586942535594

# %% [markdown]
# Plots of the heatmaps

# %%
set_global_seed(42)

plot_pca_profit_difference("Heatmap Insert and Swap NS_AE", descriptors, results['insert - swap'], scaler=scaler, pca=pca, title=r"Heatmap Insert - Swap in the autoencoder-based PCA space", axis_limits=axis_limits, color_range=color_range)
plot_pca_profit_difference("Heatmap Insert and 2-opt NS_AE", descriptors, results['insert - two_opt'], scaler=scaler, pca=pca, title=r"Heatmap Insert - Two-opt in the autoencoder-based PCA space", axis_limits=axis_limits, color_range=color_range)
plot_pca_profit_difference("Heatmap Swap and 2-opt NS_AE", descriptors, results['swap - two_opt'], scaler=scaler, pca=pca, title=r"Heatmap Swap - Two-opt in the autoencoder-based PCA space", axis_limits=axis_limits, color_range=color_range)

descriptors = compute_descriptors_NS_F(training_set)

plot_pca_profit_difference("Heatmap Insert and Swap NS_F", descriptors, results['insert - swap'], scaler=scaler_2, pca=pca_2, title=r"Heatmap Insert - Swap in the feature-based PCA space", axis_limits=axis_limits_2, color_range=color_range)
plot_pca_profit_difference("Heatmap Insert and 2-opt NS_F", descriptors, results['insert - two_opt'], scaler=scaler_2, pca=pca_2, title=r"Heatmap Insert - Two-opt in the feature-based PCA space", axis_limits=axis_limits_2, color_range=color_range)
plot_pca_profit_difference("Heatmap Swap and 2-opt NS_F", descriptors, results['swap - two_opt'], scaler=scaler_2, pca=pca_2, title=r"Heatmap Swap - Two-opt in the feature-based PCA space", axis_limits=axis_limits_2, color_range=color_range)

# %% [markdown]
# Define overlapping instances

# %%
from sklearn.metrics import pairwise_distances
import numpy as np

def count_close_neighbors(descriptors, previas=None, threshold=0.03):
    X = np.asarray(descriptors)
    n = len(X)

    if n <= 1:
        within_min = np.full(n, np.inf)
    else:
        d_self = pairwise_distances(X)
        np.fill_diagonal(d_self, np.inf)
        within_min = d_self.min(axis=1)

    if previas is None or len(previas) == 0:
        prev_min = np.full(n, np.inf)
    else:
        P = np.asarray(previas)
        prev_min = pairwise_distances(X, P).min(axis=1)

    has_close = (within_min < threshold) | (prev_min < threshold)

    n_close = int(has_close.sum())
    n_without = n - n_close

    min_global = np.minimum(within_min, prev_min)
    return n_close, n_without, min_global


def overlap_analysis(descriptors, name, threshold=0.03, previas=None, devolver_distancias=False):
    n_close, n_far, dmins = count_close_neighbors(
        descriptors, previas=previas, threshold=threshold
    )
    print(f"{name} — Overlapping instances (<{threshold}): {n_close}, Non-overlapping instances: {n_far}")
    return (n_close, n_far, dmins) if devolver_distancias else (n_close, n_far)

# %% [markdown]
# Compute overlapping instances

# %%
# Only generated instances
overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_250_NS_F_IP, swap_250_NS_F_IP, two_opt_250_NS_F_IP))),
    "250 NS_F in NS_F"
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_250_NS_F_IP, swap_250_NS_F_IP, two_opt_250_NS_F_IP))),
    "250 NS_F in NS_AE", threshold=0.3
)

overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP))),
    "1000 NS_F in NS_F"
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP))),
    "1000 NS_F in NS_AE", threshold=0.3
)

overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_250_NS_AE_IP, swap_250_NS_AE_IP, two_opt_250_NS_AE_IP))),
    "250 NS_AE in NS_F"
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_250_NS_AE_IP, swap_250_NS_AE_IP, two_opt_250_NS_AE_IP))),
    "250 NS_AE in NS_AE", threshold=0.3
)

overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP))),
    "1000 NS_AE in NS_F"
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP))),
    "1000 NS_AE in NS_AE", threshold=0.3
)

overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP,
                                            insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP))),
    "1000 all in NS_F"
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP,
                                            insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP))),
    "1000 all in NS_AE", threshold=0.3
)

# Only instances (without benchmark)
overlap_analysis(
    compute_descriptors_NS_F(training_set),
    "Solo instances"
)

overlap_analysis(
    compute_descriptors_NS_AE(training_set),
    "Solo instances", threshold=0.3
)

# With benchmark

print("----With benchmark----")
overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_250_NS_F_IP, swap_250_NS_F_IP, two_opt_250_NS_F_IP))),
    "250 NS_F in NS_F", threshold=0.03, previas=compute_descriptors_NS_F(training_set)
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_250_NS_F_IP, swap_250_NS_F_IP, two_opt_250_NS_F_IP))),
    "250 NS_F in NS_AE", threshold=0.3, previas=compute_descriptors_NS_AE(training_set)
)

overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP))),
    "1000 NS_F in NS_F", threshold=0.03, previas=compute_descriptors_NS_F(training_set)
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP))),
    "1000 NS_F in NS_AE", threshold=0.3, previas=compute_descriptors_NS_AE(training_set)
)

overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_250_NS_AE_IP, swap_250_NS_AE_IP, two_opt_250_NS_AE_IP))),
    "250 NS_AE in NS_F", threshold=0.03, previas=compute_descriptors_NS_F(training_set)
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_250_NS_AE_IP, swap_250_NS_AE_IP, two_opt_250_NS_AE_IP))),
    "250 NS_AE in NS_AE", threshold=0.3, previas=compute_descriptors_NS_AE(training_set)
)

overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP))),
    "1000 NS_AE in NS_F", threshold=0.03, previas=compute_descriptors_NS_F(training_set)
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP))),
    "1000 NS_AE in NS_AE", threshold=0.3, previas=compute_descriptors_NS_AE(training_set)
)

overlap_analysis(
    compute_descriptors_NS_F(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP,
                                            insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP))),
    "1000 all in NS_F", threshold=0.03, previas=compute_descriptors_NS_F(training_set)
)

overlap_analysis(
    compute_descriptors_NS_AE(np.concatenate((insert_1000_NS_AE_IP, swap_1000_NS_AE_IP, two_opt_1000_NS_AE_IP,
                                            insert_1000_NS_F_IP, swap_1000_NS_F_IP, two_opt_1000_NS_F_IP))),
    "1000 all in NS_AE", threshold=0.3, previas=compute_descriptors_NS_AE(training_set)
)
# Out:
# 250 NS_F in NS_F — Overlapping instances (<0.03): 8, Non-overlapping instances: 2657
# 250 NS_F in NS_AE — Overlapping instances (<0.3): 2045, Non-overlapping instances: 620
# 1000 NS_F in NS_F — Overlapping instances (<0.03): 14, Non-overlapping instances: 5432
# 1000 NS_F in NS_AE — Overlapping instances (<0.3): 4822, Non-overlapping instances: 624
# 250 NS_AE in NS_F — Overlapping instances (<0.03): 1267, Non-overlapping instances: 948
# 250 NS_AE in NS_AE — Overlapping instances (<0.3): 16, Non-overlapping instances: 2199
# 1000 NS_AE in NS_F — Overlapping instances (<0.03): 3746, Non-overlapping instances: 1080
# 1000 NS_AE in NS_AE — Overlapping instances (<0.3): 15, Non-overlapping instances: 4811
# 1000 all in NS_F — Overlapping instances (<0.03): 4140, Non-overlapping instances: 6132
# 1000 all in NS_AE — Overlapping instances (<0.3): 4976, Non-overlapping instances: 5296
# Solo instances — Overlapping instances (<0.03): 1091, Non-overlapping instances: 2609
# ...
